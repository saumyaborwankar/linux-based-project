# %%
import cv2
import numpy as np
x=cv2.VideoCapture(0)

for i in range(3):
    stat,photo=x.read()
    
    cv2.imwrite('D:/opencv_photo/photo{}.jpeg'.format(i),photo)
    cv2.waitKey(1)
    cv2.destroyAllWindows() 
x.release()
